# %%
import matplotlib.pyplot as plt

# %%
scores = [35,45,50,55,60,65,70,75,80,92]

# %%
plt.hist(scores)
plt.show()

# %%
plt.boxplot(scores)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1acab6ea490>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1acab6ea710>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1acab6ea350>],
#  'medians': [<matplotlib.lines.Line2D at 0x1acab6ea990>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1acab6eaad0>],
#  'means': []}

# %%
import numpy as np
data = np.random.normal(loc=70,scale=10,size=1000)
data
# Out:
# array([ 61.66229452,  69.58038835,  67.13055327,  70.30535853,
#         68.54336399,  65.32688335,  87.05084428,  72.08030205,
#         86.68377361,  78.17964342,  60.72287781,  71.56081021,
#         70.28007135,  66.89890772,  65.27622229,  68.20526692,
#         61.55852741,  68.45253387,  56.89206285,  71.35869472,
#         54.64185613,  53.62080427,  76.92970114,  80.37962609,
#         64.34928939,  76.82189306,  58.61846091,  61.54623098,
#         49.92700919,  73.37840825,  90.24061899,  77.33056126,
#         59.62589154,  62.59106273,  80.16052974,  72.82848523,
#         86.80505742,  86.8284811 ,  57.8580577 ,  59.08971212,
#         80.24673663,  76.05673384,  81.70472259,  59.09424653,
#         63.05573333,  65.32439549,  73.47136023,  73.34385553,
#         50.67684606,  73.31136756,  57.02603706,  75.94586281,
#         54.00524187,  77.8839095 ,  59.70832441,  74.96492684,
#         68.24553475,  80.35814713,  73.80670978,  74.27355089,
# ...

# %%
plt.hist(data)
# Out:
# (array([  8.,  23.,  86., 180., 242., 252., 133.,  60.,  13.,   3.]),
#  array([ 37.73468776,  44.42454217,  51.11439659,  57.804251  ,
#          64.49410541,  71.18395982,  77.87381424,  84.56366865,
#          91.25352306,  97.94337748, 104.63323189]),
#  <BarContainer object of 10 artists>)

# %%
income = [20000,22000,25000,26000,28000,30000,500000]

# %%
import pandas as pd
df2 = pd.DataFrame(income)
df2
# Out:
#         0
# 0   20000
# 1   22000
# 2   25000
# 3   26000
# 4   28000
# 5   30000
# 6  500000

# %%
plt.hist(income)
# Out:
# (array([6., 0., 0., 0., 0., 0., 0., 0., 0., 1.]),
#  array([ 20000.,  68000., 116000., 164000., 212000., 260000., 308000.,
#         356000., 404000., 452000., 500000.]),
#  <BarContainer object of 10 artists>)

# %%
scores =[40,60,75,80,85,90,95,98]

# %%
plt.hist(scores) #Negative scale or left skew most of the data is on the left side
# Out:
# (array([1., 0., 0., 1., 0., 0., 2., 1., 1., 2.]),
#  array([40. , 45.8, 51.6, 57.4, 63.2, 69. , 74.8, 80.6, 86.4, 92.2, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
# Check the standard deviation to determine the whether to use the mean

# %%
population = np.random.normal(70,10,1000)
sample = np.random.choice(population,size=50)
population.mean()
# Out:
# np.float64(69.87834060569737)

# %%
sample.mean
# Out:
# <function ndarray.mean>

# %%
df3= pd.DataFrame(population,columns=['population'])
df4= pd.DataFrame(sample,columns=['sample'])

# %%
df3.describe()
# Out:
#         population
# count  1000.000000
# mean     69.878341
# std      10.137462
# min      40.783030
# 25%      62.760048
# 50%      69.979258
# 75%      77.020829
# max     104.059613

# %%
df4.describe()
# Out:
#           sample
# count  50.000000
# mean   70.725458
# std     9.269055
# min    42.319251
# 25%    65.667162
# 50%    72.142123
# 75%    74.777909
# max    87.298769
